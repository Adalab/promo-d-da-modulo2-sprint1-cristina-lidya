# %% [markdown]
# # **Ejercicios de pair programming Módulo 2 Sprint 1**
# ## **Visualización: Lección 3**
# ### **Seaborn**

# %% [markdown]
# En este ejercicio, de nuevo, trabajaremos con el csv que generamos en el ejercicio de pair programming de Pandas V, ese en el que habíamos unido distintos csv en uno.
#
# En estos ejercicios aprenderemos a hacer algunas gráficas usando la librería seaborn. Igual que el ejercicio anterior de pair programming, para solucionar algunas preguntas tendréis que usar métodos y herramientas aprendidas anteriormente como groupby, value_counts, rename, filtrado de datos, etc.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as datetime

# %% [markdown]
# 1. Usando la librería seaborn, cread una gráfica que nos muestre el número de personas que han hecho una solicitud de ticket en cada año. Hacedlo solo para los del tipo "Problema".

# %%
df_años = pd.read_csv("../pandas/data/datos_guardados/años_2016_2020.csv")
df_años
# Out:
#                id_ticket   año                fecha  id_empleado  id_agente  \
# 0      GDDENR-5042564453  2016           2016-07-13       1735.0        4.0
# 1      GDDENR-8042508060  2016           2016-05-18       1566.0       10.0
# 2      GDDESR-1342539995  2016           2016-06-18        569.0       29.0
# 3      GDDTSR-5942488006  2016           2016-04-28        320.0       40.0
# 4      GDLEER-0042524120  2016           2016-06-03       1842.0       31.0
# ...                  ...   ...                  ...          ...        ...
# 97381  TWRTSR-8543883120  2020  2020-02-22 00:00:00       1142.0        1.0
# 97382  TWRTSR-8744097039  2020  2020-09-23 00:00:00        223.0       40.0
# 97383  TWRTSR-9643846768  2020  2020-01-16 00:00:00        256.0        7.0
# 97384  TWRTSR-9944138906  2020  2020-11-03 00:00:00       1060.0        9.0
# 97385  TWRTST-8643986162  2020  2020-06-04 00:00:00       1876.0       41.0
#
#            categoría       tipo           severidad        prioridad  \
# 0      Acceso&%Login   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 1      Acceso&%Login   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 2            Sistema   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 3            Sistema  Solicitud  0 - Sin Clasificar  0 - Sin Asignar
# 4           Software   Problema          2 - Normal  0 - Sin Asignar
# ...              ...        ...                 ...              ...
# 97381        Sistema  Solicitud           3 - Mayor         1 - Baja
# 97382        Sistema  Solicitud           1 - Menor         1 - Baja
# 97383        Sistema  Solicitud           3 - Mayor         1 - Baja
# 97384        Sistema  Solicitud           1 - Menor         1 - Baja
# 97385        Sistema  Solicitud           1 - Menor         1 - Baja
#
#        días_resolución  satisfacción
# 0                  0.0           5.0
# 1                  0.0           5.0
# 2                  3.0           5.0
# 3                  9.0           5.0
# 4                  0.0           5.0
# ...                ...           ...
# 97381             11.0           5.0
# 97382              7.0           4.0
# 97383             13.0           5.0
# 97384              9.0           5.0
# 97385              6.0           4.0
#
# [97386 rows x 11 columns]

# %%
plt.figure(figsize= (8,4))
fig = sns.countplot(x = "año", data = df_años, hue = "tipo")
fig.set(xlabel = "Años", ylabel = "número de incidencencias por año")
fig.set_title("Incidencias en los últimos cinco años")
plt.show()

# %%
tipo = df_años.groupby("tipo")

# %%
tipo.ngroups
# Out:
# 2

# %%
problema = tipo.get_group("Problema")
problema
# Out:
#                id_ticket   año                fecha  id_empleado  id_agente  \
# 0      GDDENR-5042564453  2016           2016-07-13       1735.0        4.0
# 1      GDDENR-8042508060  2016           2016-05-18       1566.0       10.0
# 2      GDDESR-1342539995  2016           2016-06-18        569.0       29.0
# 4      GDLEER-0042524120  2016           2016-06-03       1842.0       31.0
# 5      GDLEER-0142608095  2016           2016-08-26         59.0       20.0
# ...                  ...   ...                  ...          ...        ...
# 97344  TWRESR-7244098112  2020  2020-09-24 00:00:00       1891.0       41.0
# 97345  TWRESR-8044058342  2020  2020-08-15 00:00:00        394.0       33.0
# 97346  TWRESR-8443962836  2020  2020-05-11 00:00:00        403.0        8.0
# 97347  TWRESR-9544015158  2020  2020-07-03 00:00:00        935.0       31.0
# 97348  TWREST-6744042617  2020  2020-07-30 00:00:00        681.0       36.0
#
#            categoría      tipo           severidad        prioridad  \
# 0      Acceso&%Login  Problema  0 - Sin Clasificar  0 - Sin Asignar
# 1      Acceso&%Login  Problema  0 - Sin Clasificar  0 - Sin Asignar
# 2            Sistema  Problema  0 - Sin Clasificar  0 - Sin Asignar
# 4           Software  Problema          2 - Normal  0 - Sin Asignar
# 5           Software  Problema          2 - Normal  0 - Sin Asignar
# ...              ...       ...                 ...              ...
# 97344        Sistema  Problema           3 - Mayor         1 - Baja
# 97345        Sistema  Problema           3 - Mayor         1 - Baja
# 97346        Sistema  Problema           1 - Menor         1 - Baja
# 97347        Sistema  Problema           3 - Mayor         1 - Baja
# 97348        Sistema  Problema           3 - Mayor         1 - Baja
#
#        días_resolución  satisfacción
# 0                  0.0           5.0
# 1                  0.0           5.0
# 2                  3.0           5.0
# 4                  0.0           5.0
# 5                  1.0           1.0
# ...                ...           ...
# 97344              2.0           5.0
# 97345             10.0           4.0
# 97346              4.0           4.0
# 97347              5.0           5.0
# 97348              7.0           5.0
#
# [24248 rows x 11 columns]

# %%
plt.figure(figsize= (8,4))
fig = sns.countplot(x = "año", hue =  "tipo", data = problema)
fig.set(xlabel = "Años", ylabel = "número de incidencias por año")
fig.set_title("Incidencias en los últimos cinco años")
plt.show()

# %% [markdown]
# 2. La gráfica anterior nos ha mostrado una tendencia ascendente en el número de solicitudes a lo largo de los años, lo que preocupa a la empresa, por lo que quieren seguir analizando los datos para ver si son capaces de identificar los problemas subyacentes a estas solicitudes. Para esto, quieren saber si hay diferencias a lo largo del año. En concreto nos piden que hagamos un subplot con seaborn donde:
#
# - En la primera gráfica tengamos la gráfica que creamos en el ejercicio anterior
# - En la segunda gráfica tengamos la comparación por años y semestres para el número de tikects de tipo "Problema".

# %%
df_años["fecha"] = df_años["fecha"].apply(pd.to_datetime)

# %%
df_años.dtypes
# Out:
# id_ticket                  object
# año                         int64
# fecha              datetime64[ns]
# id_empleado               float64
# id_agente                 float64
# categoría                  object
# tipo                       object
# severidad                  object
# prioridad                  object
# días_resolución           float64
# satisfacción              float64
# semestre                   object
# dtype: object

# %%
df_años["fecha"].dt.month
# Out:
# 0         7
# 1         5
# 2         6
# 3         4
# 4         6
#          ..
# 97381     2
# 97382     9
# 97383     1
# 97384    11
# 97385     6
# Name: fecha, Length: 97386, dtype: int64

# %%
df_años["semestre"] = np.where(df_años["fecha"].dt.month< 7, "1er semestre", "2do semestre")

# %%
df_años["semestre"].unique()
# Out:
# array(['2do semestre', '1er semestre'], dtype=object)

# %%
df_años
# Out:
#                id_ticket   año      fecha  id_empleado  id_agente  \
# 0      GDDENR-5042564453  2016 2016-07-13       1735.0        4.0
# 1      GDDENR-8042508060  2016 2016-05-18       1566.0       10.0
# 2      GDDESR-1342539995  2016 2016-06-18        569.0       29.0
# 3      GDDTSR-5942488006  2016 2016-04-28        320.0       40.0
# 4      GDLEER-0042524120  2016 2016-06-03       1842.0       31.0
# ...                  ...   ...        ...          ...        ...
# 97381  TWRTSR-8543883120  2020 2020-02-22       1142.0        1.0
# 97382  TWRTSR-8744097039  2020 2020-09-23        223.0       40.0
# 97383  TWRTSR-9643846768  2020 2020-01-16        256.0        7.0
# 97384  TWRTSR-9944138906  2020 2020-11-03       1060.0        9.0
# 97385  TWRTST-8643986162  2020 2020-06-04       1876.0       41.0
#
#            categoría       tipo           severidad        prioridad  \
# 0      Acceso&%Login   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 1      Acceso&%Login   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 2            Sistema   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 3            Sistema  Solicitud  0 - Sin Clasificar  0 - Sin Asignar
# 4           Software   Problema          2 - Normal  0 - Sin Asignar
# ...              ...        ...                 ...              ...
# 97381        Sistema  Solicitud           3 - Mayor         1 - Baja
# 97382        Sistema  Solicitud           1 - Menor         1 - Baja
# 97383        Sistema  Solicitud           3 - Mayor         1 - Baja
# 97384        Sistema  Solicitud           1 - Menor         1 - Baja
# 97385        Sistema  Solicitud           1 - Menor         1 - Baja
#
#        días_resolución  satisfacción      semestre
# 0                  0.0           5.0  2do semestre
# 1                  0.0           5.0  1er semestre
# 2                  3.0           5.0  1er semestre
# 3                  9.0           5.0  1er semestre
# 4                  0.0           5.0  1er semestre
# ...                ...           ...           ...
# 97381             11.0           5.0  1er semestre
# 97382              7.0           4.0  2do semestre
# 97383             13.0           5.0  1er semestre
# 97384              9.0           5.0  2do semestre
# 97385              6.0           4.0  1er semestre
#
# [97386 rows x 12 columns]

# %%
df_años.sample(5)
# Out:
#                id_ticket   año      fecha  id_empleado  id_agente  \
# 38858  KWRESR-7743249329  2018 2018-05-29       1302.0       33.0
# 52933  GWLTSR-1543798739  2019 2019-11-29        243.0       47.0
# 91687  TDLESR-1343966463  2020 2020-05-15        466.0       24.0
# 93458  THLENR-6043945928  2020 2020-04-24       1912.0        9.0
# 20598  KMLTET-7542907607  2017 2017-06-21       1890.0        6.0
#
#           categoría       tipo   severidad        prioridad  días_resolución  \
# 38858       Sistema   Problema   1 - Menor         1 - Baja              7.0
# 52933       Sistema  Solicitud  2 - Normal         1 - Baja              5.0
# 91687       Sistema   Problema  2 - Normal  0 - Sin Asignar              3.0
# 93458  Acceso/Login   Problema  2 - Normal         3 - Alta              0.0
# 20598      Software  Solicitud  2 - Normal        2 - Media              2.0
#
#        satisfacción      semestre
# 38858           4.0  1er semestre
# 52933           5.0  2do semestre
# 91687           5.0  1er semestre
# 93458           4.0  1er semestre
# 20598           4.0  1er semestre

# %%
fig,ax = plt.subplots(1,2)


ax[0].sns.countplot(x = "año", hue =  "tipo", data = problema)
ax[0].set_xlabel("Años")
ax[0].set_ylabel("número de incidencias por año")
ax[0].set_title("Incidencias en los últimos cinco años")



plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_597/2340114269.py in <module>
#       2
#       3
# ----> 4 ax[0].sns.countplot(x = "año", hue =  "tipo", data = problema)
#       5 ax[0].set_xlabel("Años")
#       6 ax[0].set_ylabel("número de incidencias por año")
#
# AttributeError: 'AxesSubplot' object has no attribute 'sns'

# %% [markdown]
# 3. La empresa se siente algo aliviada al ver que no hay diferencias entre semestres, pero seguimos sin identificar porque cada año tenemos más solicitudes. Nuestras jefas quieren saber ahora, que prioridad tienen los tickets que tenemos en el conjunto de datos. Por eso nos piden que volvamos a hacer un subplot:
#
# - En la primera gráfica deberíamos tener la gráfica creada en el ejercicio 1
# - En la segunda gráfica deberíamos incluir el número de tickets por año en función de la prioridad que tienen.

# %%
fig, ax = plt.subplots(1,2)
ax[0].sns.countplot(x = "año", hue =  "tipo", data = problema)
ax[0].set_xlabel("Años")
ax[0].set_ylabel("número de incidencias por año")
ax[0].set_title("Incidencias en los últimos cinco años")
ax[1].sns.countplot(x = "id_ticket", hue = "prioridad", data = df_años)
ax[1].set_xlabel()
ax[1].set_ylabel()
plt.show()

# %% [markdown]
# 4. Hasta ahora hemos estado viendo que no parece que haya nada alarmante. Por lo que ahora quieren que evaluemos la cantidad de trabajo que cada empleado esta haciendo, para poder identificar rápidamente un problema en la distribución de tareas y tomar medidas para solucionarlo. Para ello nos piden que hagamos dos gráficas en un subplot:
#
# - La primera gráfica tiene que tener los 5 empleados con mayor número de tickets, deberemos mostrar quienes son y cuál es total de tickets que atienden cada uno.
#
# - La primera gráfica tiene que tener los 5 empleados con menor número de tickets, deberemos mostrar quienes son y cuál es total de tickets que atienden cada uno.
#
# 📌 NOTA Somos analistas y no nos vale con sacar las gráficas. Incluid una celda de markdown donde expliqueis que es lo que estamos viendo en las gráficas, es decir, haced una interpretación de los resultados.
