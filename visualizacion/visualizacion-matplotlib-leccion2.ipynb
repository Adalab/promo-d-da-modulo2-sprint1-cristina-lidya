# %% [markdown]
# # **Ejercicios de pair programming Módulo 2 Sprint 1**
# ## **Visualización: Lección 2**
# ### **MatPlotLib II**

# %% [markdown]
# Sigamos con más visualizaciones. En este caso trabajaremos con el csv que generamos en el ejercicio de pair programming de Pandas V, ese en el que habíamos unido distintos csv en uno. Al final nos habíamos quedado con los siguientes conjuntos de datos:
#
# - El fichero de la unión de todos los conjuntos de datos de los distintos años
# - El fichero con la unión de los datos de puestos y empleados.
# - El fichero de los agentes.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
años_2016_2020 = pd.read_csv("../pandas/data/datos_guardados/años_2016_2020.csv")
años_2016_2020
# Out:
#                id_ticket   año                fecha  id_empleado  id_agente  \
# 0      GDDENR-5042564453  2016           2016-07-13       1735.0        4.0
# 1      GDDENR-8042508060  2016           2016-05-18       1566.0       10.0
# 2      GDDESR-1342539995  2016           2016-06-18        569.0       29.0
# 3      GDDTSR-5942488006  2016           2016-04-28        320.0       40.0
# 4      GDLEER-0042524120  2016           2016-06-03       1842.0       31.0
# ...                  ...   ...                  ...          ...        ...
# 97381  TWRTSR-8543883120  2020  2020-02-22 00:00:00       1142.0        1.0
# 97382  TWRTSR-8744097039  2020  2020-09-23 00:00:00        223.0       40.0
# 97383  TWRTSR-9643846768  2020  2020-01-16 00:00:00        256.0        7.0
# 97384  TWRTSR-9944138906  2020  2020-11-03 00:00:00       1060.0        9.0
# 97385  TWRTST-8643986162  2020  2020-06-04 00:00:00       1876.0       41.0
#
# ...

# %%
empleados_puestos = pd.read_csv("../pandas/data/datos_guardados/empleados_puestos.csv")
empleados_puestos
# Out:
#      turno  id_empleado    apellido    nombre id_puesto  \
# 0        A          6.0       VILLA     JESUS  50-32200
# 1      NaN         60.0        DIAZ  PATRICIA  50-32200
# 2        B          2.0      DUARTE   ANTONIO  50-32200
# 3      NaN         24.0  VILLANUEVA     JESUS  50-32200
# 4      NaN         98.0    GALLEGOS  PATRICIA  50-32200
# ...    ...          ...         ...       ...       ...
# 2017   NaN          NaN         NaN       NaN  80-27000
# 2018   NaN          NaN         NaN       NaN  90-14110
# 2019   NaN          NaN         NaN       NaN  90-18000
# 2020   NaN          NaN         NaN       NaN  90-23200
# 2021   NaN          NaN         NaN       NaN  90-26100
#
#                                 email                            puesto  \
# 0           jesus.villa@tractchun.com           Comprador de Materiales
# 1         patricia.diaz@tractchun.com           Comprador de Materiales
# 2        antonio.duarte@tractchun.com           Comprador de Materiales
# ...

# %%
agentes = pd.read_csv("../pandas/data/datos_guardados/agentes_procesado.csv", index_col = 0)
agentes.head()
# Out:
#    id_agente               nombre                              email  \
# 0          1          Mata Lucero          lucero.mata@tractchun.com
# 1          2         JesusGrajeda        jesus.grajeda@tractchun.com
# 2          3          Elena Velez          elena.velez@tractchun.com
# 3          4      Barraza Alberto      alberto.barraza@tractchun.com
# 4          5  Willyberto Gonzales  willyberto.gonzales@tractchun.com
#
#   fecha_de_nacimiento
# 0           1989/4/28
# 1            1979/1/1
# 2            1993/6/6
# 3          1978/10/20
# 4           1973/5/11

# %% [markdown]
# 📌 NOTA Os dejamos abajo los ficheros por si no os hubiera dado tiempo a tenerlos preparados
#
# El objetivo de hoy, mejorar algunas de las gráficas que hicimos en el ejericio de pair programming de ayer y crear algunas nuevas aprovechando que tenemos algunas columnas nuevas en dataframe.
#
# Las preguntas que tendréis que contestar son:

# %% [markdown]
# 1. Ayer creamos un par de gráficas para los tickets de la categoría "Software" y "Hardware", donde visualizamos el número de clientes que teníamos en cada grupo de satisfacción. Hoy tendréis que hacer dos gráficas con subplots:
#
# . En la primera debéis mostrar la cantidad de tickets en función del tipo (si es Problema o Solicitud), cada subplot corresponderá a cada una de las categorías. Debéis:
#
#     - Poner nombre a los ejes de cada uno de los subplots
#     - Poner un títulos a cada uno de los subplots
#     - Poner el color de las líneas en negro.
#     - Establecer el tamaño de la gráfica a 15 x 5
#     - Ponerle marcadores a las gráficas
#     - No incluir leyenda

# %%
software = años_2016_2020[años_2016_2020["categoría"] == "Software"].reset_index()

# %%
hardware = años_2016_2020[años_2016_2020["categoría"] == "Hardware"].reset_index()

# %%
numero_tickets_software = software["tipo"].value_counts().reset_index()
numero_tickets_software
# Out:
#        index   tipo
# 0  Solicitud  14618
# 1   Problema   4925

# %%
numero_tickets_hardware = hardware["tipo"].value_counts().reset_index()
numero_tickets_hardware
# Out:
#        index  tipo
# 0  Solicitud  7356
# 1   Problema  2361

# %%
fig,ax = plt.subplots(1, 2, figsize = (15, 5))
ax[0].bar(x = numero_tickets_software["index"], height = numero_tickets_software["tipo"])
ax[1].bar(x = numero_tickets_hardware["index"], height = numero_tickets_hardware["tipo"])
ax[0].set_xlabel("Tipo")
ax[0].set_ylabel("Cantidad de tickets")
ax[1].set_xlabel("Tipo")
ax[1].set_ylabel("Cantidad de tickets")
ax[0].set_title("Tickets por tipo para incidencias de software")
ax[1].set_title("Tickets por tipo para incidencias de hardware")
ax[0].grid(color = "k", linestyle = "-")
ax[1].grid(color = "k", linestyle = "-")
plt.show()

# %% [markdown]
# . En la segunda debéis mostrar el número de tickets en función de la satisfacción.
#
#     - De nuevo tendréis que ponerle nombre a los ejes y título a cada gráfica.
#     - En este caso el subplot deberá tener dos filas y una columna
#     - No incluir leyenda
#     - Cambiar el color de las barras

# %%
satisfaccion_software = software["satisfacción"].reset_index()
satisfaccion_software
# Out:
#        index  satisfacción
# 0          0           5.0
# 1          1           1.0
# 2          2           1.0
# 3          3           5.0
# 4          4           5.0
# ...      ...           ...
# 19538  19538           5.0
# 19539  19539           5.0
# 19540  19540           5.0
# 19541  19541           5.0
# 19542  19542           4.0
#
# [19543 rows x 2 columns]

# %%
satisfaccion_hardware = hardware["satisfacción"].reset_index()
satisfaccion_hardware
# Out:
#       index  satisfacción
# 0         0           5.0
# 1         1           5.0
# 2         2           5.0
# 3         3           5.0
# 4         4           5.0
# ...     ...           ...
# 9712   9712           5.0
# 9713   9713           5.0
# 9714   9714           5.0
# 9715   9715           5.0
# 9716   9716           5.0
#
# [9717 rows x 2 columns]

# %%
fig,ax = plt.subplots(2,1, figsize = (5, 10))
ax[0].bar(height = satisfaccion_software["index"], x = satisfaccion_software["satisfacción"], color = "green")
ax[1].bar(height = satisfaccion_hardware["index"], x = satisfaccion_hardware["satisfacción"], color = "purple")
ax[0].set_ylabel("Cantidad de tickets")
ax[0].set_xlabel("Índice de Satisfacción")
ax[1].set_ylabel("Cantidad de tickets")
ax[1].set_xlabel("Índice de Satisfacción")
ax[0].set_title("Satisfacción para incidencias software")
ax[1].set_title("Satisfacción para incidencias de hardware")
plt.show()

# %% [markdown]
# 2. Cread un subplot con dos gráficas, dónde en la primera tengamos el número de empleados por departamento y en la otra por tipo de puesto. Debéis:
#
#     - Poner leyenda a la gráfica
#     - Cada línea debe ir en un color
#     - Ponerle nombre a los ejes y a la gráfica.
#     - Poner marcadores a las lineas.

# %%
empleados_puestos
# Out:
#      turno  id_empleado    apellido    nombre id_puesto  \
# 0        A          6.0       VILLA     JESUS  50-32200
# 1      NaN         60.0        DIAZ  PATRICIA  50-32200
# 2        B          2.0      DUARTE   ANTONIO  50-32200
# 3      NaN         24.0  VILLANUEVA     JESUS  50-32200
# 4      NaN         98.0    GALLEGOS  PATRICIA  50-32200
# ...    ...          ...         ...       ...       ...
# 2017   NaN          NaN         NaN       NaN  80-27000
# 2018   NaN          NaN         NaN       NaN  90-14110
# 2019   NaN          NaN         NaN       NaN  90-18000
# 2020   NaN          NaN         NaN       NaN  90-23200
# 2021   NaN          NaN         NaN       NaN  90-26100
#
#                                 email                            puesto  \
# 0           jesus.villa@tractchun.com           Comprador de Materiales
# 1         patricia.diaz@tractchun.com           Comprador de Materiales
# 2        antonio.duarte@tractchun.com           Comprador de Materiales
# ...

# %%
numero_empleados_dpto = empleados_puestos.groupby("departamento")["id_empleado"].count().reset_index()
numero_empleados_dpto
# Out:
#                                    departamento  id_empleado
# 0   AUDITORIA INTERNA, CALIBRACION Y METROLOGIA           70
# 1                                  CONTABILIDAD           25
# 2                         CONTROL DE PRODUCCION          127
# 3                         INGENIERIA DE CALIDAD          395
# 4                     INGENIERIA DE MANUFACTURA          228
# 5                                 MANTENIMIENTO          258
# 6                                    MATERIALES          125
# 7                                      PERSONAL           20
# 8                                    PRODUCCION          475
# 9                              Recursos Humanos          117
# 10                  SISTEMAS, TRAFICO Y ADUANAS          160

# %%
numero_empleados_puesto = empleados_puestos.groupby("tipo_puesto")["id_empleado"].count().reset_index()
numero_empleados_puesto
# Out:
#       tipo_puesto  id_empleado
# 0  Administrativo          321
# 1        Gerencia           42
# 2   Mandos Medios         1060
# 3       Operativo          577

# %%
fig,ax = plt.subplots(2, 1, figsize = (8, 4))
ax[0].plot(x = numero_empleados_dpto["departamento"], height = numero_empleados_dpto["id_empleado"], color = "limegreen", marker = "*")
ax[1].plot(x = numero_empleados_puesto["tipo_puesto"], height = numero_empleados_puesto["id_empleado"], color = "darkcyan", marker = "*")
ax[0].set_xlabel("Nombre departamento")
ax[0].set_ylabel("Cantidad de empleados")
ax[1].set_xlabel("Tipo de puesto")
ax[1].set_ylabel("Cantidad de empleados")
ax[0].set_title("Número de empleados por departamento")
ax[1].set_title("Número de empleados por tipo de puesto")
plt.show()

# %%
fig,ax = plt.subplots(2, 1, figsize = (25, 10))
ax[0].plot(numero_empleados_dpto["departamento"], numero_empleados_dpto["id_empleado"], color = "limegreen", marker = "d", markersize = 6)
ax[1].plot(numero_empleados_puesto["tipo_puesto"], numero_empleados_puesto["id_empleado"], color = "darkcyan", marker = "d", markersize = 6)
ax[0].set_xlabel("Nombre departamento")
ax[0].set_ylabel("Cantidad de empleados")
ax[1].set_xlabel("Tipo de puesto")
ax[1].set_ylabel("Cantidad de empleados")
ax[0].tick_params(axis='x', labelrotation = 10)
ax[0].set_title("Número de empleados por departamento")
ax[1].set_title("Número de empleados por tipo de puesto")
plt.show()

# %% [markdown]
# 3. Guardad las figuras creadas en cada caso. Podéis usar el formato que queráis. Guarda todas las fotos en una carpeta llamada Visualizacion-II.

# %%
# Las figuras están guardadas de forma manual en una carpeta creada según se indica, ya que no se había añadido el código de guardado al crear cada gráfica.
