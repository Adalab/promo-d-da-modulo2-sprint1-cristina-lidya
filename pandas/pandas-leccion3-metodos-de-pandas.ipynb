# %% [markdown]
# # **Ejercicios de pair programming Módulo 2 Sprint 1**
# ## **Pandas: Lección 3**
# ### **Métodos de pandas**

# %% [markdown]
# De aquí en adelante, vamos a trabajar con una serie de dataframes donde tenemos información sobre una empresa que se decica a la atención al cliente para resolver problemas con los sistemas. Esta empresa se dedica a brindar soluciones de software y hardware para usuarios que experimentan problemas técnicos en sus dispositivos electrónicos, ya sea en computadoras, laptops, teléfonos móviles u otros dispositivos. Ofrecen servicios de reparación, diagnóstico, instalación y configuración de software y hardware, con el objetivo de ayudar a los clientes a resolver sus problemas técnicos y mejorar el rendimiento de sus dispositivos.
#
# Esta empresa utiliza un sistema de tickets para atender los problemas de software y hardware de sus clientes. Los usuarios pueden presentar una solicitud de soporte a través del sistema de tickets y recibir una respuesta rápida y efectiva por parte de un equipo de técnicos especializados. El sistema de tickets permite a la empresa mantener un registro detallado de todas las solicitudes y su estado actual, lo que facilita el seguimiento y la resolución de los problemas en tiempo y forma. Además, la empresa puede usar los datos recopilados para identificar patrones y tendencias comunes en los problemas y mejorar continuamente sus servicios y procesos.

# %% [markdown]
# Esta empresa utiliza un sistema de tickets para atender los problemas de software y hardware de sus clientes. Los usuarios pueden presentar una solicitud de soporte a través del sistema de tickets y recibir una respuesta rápida y efectiva por parte de un equipo de técnicos especializados. El sistema de tickets permite a la empresa mantener un registro detallado de todas las solicitudes y su estado actual, lo que facilita el seguimiento y la resolución de los problemas en tiempo y forma. Además, la empresa puede usar los datos recopilados para identificar patrones y tendencias comunes en los problemas y mejorar continuamente sus servicios y procesos.
#
# En concreto en este pair programming os hemos compartido 4 ficheros, estos son:
#
#     - Puestos.xlsx: este conjunto de datos contiene información sobre los puestos de trabajo disponibles en la empresa. Cada fila corresponde a un puesto y tiene información como su ID, nombre, departamento y tipo. La información sobre los departamentos y los tipos de puesto puede ayudar a la empresa a clasificar y organizar los puestos en función de su función y nivel de responsabilidad. Se pueden utilizar para llevar un registro de los puestos disponibles, sus descripciones y los requisitos necesarios para cada puesto. La información sobre los puestos también puede ser útil para la empresa para la planificación de la fuerza laboral, la evaluación del desempeño y la asignación de tareas. Además, los datos sobre los puestos pueden ser útiles para los empleados que buscan información sobre las oportunidades de trabajo y las descripciones de trabajo en la empresa.
#
#     - Empleados.csv: este conjunto de datos contiene información sobre los empleados de la empresa y sus turnos de trabajo. Cada fila corresponde a un empleado y tiene información como su ID, apellido, nombre, ID de puesto y correo electrónico. Estos datos se pueden utilizar para llevar un registro de los empleados, sus datos personales, su información de contacto y sus horarios de trabajo. La información sobre los turnos puede ayudar a la empresa a administrar y coordinar al personal de manera efectiva, asegurando una cobertura adecuada durante las horas de trabajo. Además, la información sobre los turnos puede ser útil para calcular las horas trabajadas por cada empleado y para la generación de nóminas.
#
#     - Agentes.csv: este conjunto de datos contiene información de los agentes de soporte técnico de la empresa. Cada fila corresponde a un agente y tiene información como el ID del agente, el nombre completo del agente, su correo electrónico y su fecha de nacimiento. Los utilizaremos para llevar un registro detallado de los agentes de soporte técnico, sus datos personales y su información de contacto. La empresa nos puede perdir como analistas de datos que administremos y coordinemos al equipo de soporte técnico, así como para realizar análisis estadísticos sobre el equipo de trabajo y sus características personales.
#
#     - 2016.xlsx: este conjunto de datos contiene información de tickets de soporte técnico de la empresa. Cada fila corresponde a un ticket y tiene información como el ID del ticket, la fecha de creación, el ID del empleado y del agente, la categoría y el tipo de problema reportado, la severidad y prioridad del problema, el tiempo que tardó en resolverse el ticket, el nivel de satisfacción del cliente, la plataforma web donde se reportó el problema y un índice. Estos datos se pueden utilizar para analizar el desempeño del equipo de soporte técnico de la empresa, identificar problemas comunes, medir la satisfacción del cliente y mejorar los procesos de soporte técnico.

# %% [markdown]
# ### Tareas a realizar en este pair programming
#
# La exploración de datos es una parte crítica del proceso de análisis de datos. Para los analistas de datos, hacer una exploración de datos con Pandas es importante por varias razones:
#
# - Comprender los datos: antes de comenzar a analizar datos, es importante comprender los datos con los que se está trabajando.
# Identificar problemas de calidad de datos: los datos pueden contener errores, valores faltantes o datos duplicados. Al utilizar Pandas, como analistas de datos podemos identificar rápidamente estos problemas y determinar la mejor manera de abordarlos antes de comenzar a analizar los datos.
#
# - Identificar patrones y tendencias: al explorar los datos con Pandas, los analistas de datos podemos identificar patrones y tendencias en los datos que pueden ayudar a generar ideas y obtener información valiosa.
#
# - En resumen, hacer una exploración de datos con Pandas es esencial para cualquier analista de datos, ya que puede ayudar a comprender los datos, identificar problemas de calidad de datos, identificar patrones y tendencias y visualizar los datos para una mejor comprensión y presentación de los resultados del análisis. En los próximos pair programmings vamos a empezar a explorar los datos para identificar posibles problemas en los datos, comprender los datos y familiarizanos con ellos.

# %% [markdown]
# 1. Cargar todos los datasets que os hemos compartido en este pair programming

# %%
import pandas as pd

# %%
empleados = pd.read_csv("data/Empleados.csv")
empleados.head()
# Out:
#   Turno  ID Empleado Apellido     Nombre ID Puesto  \
# 0     A            6    VILLA      JESUS  50-32200
# 1   NaN           10   MENDEZ    RICARDO  15-24100
# 2   NaN           21  HEREDIA  GUADALUPE  90-14000
# 3   NaN           27    DURAN    DESSENS  15-24100
# 4   NaN           29   LAGUNA   FEDERICO  80-24100
#
#                              Email
# 0        jesus.villa@tractchun.com
# 1     ricardo.mendez@tractchun.com
# 2  guadalupe.heredia@tractchun.com
# 3      dessens.duran@tractchun.com
# 4    federico.laguna@tractchun.com

# %%
agentes = pd.read_csv("data/Agentes.csv")
agentes.head()
# Out:
#    ID Agente               Nombre                              email  \
# 0          1          Mata Lucero          lucero.mata@tractchun.com
# 1          2         JesusGrajeda        jesus.grajeda@tractchun.com
# 2          3          Elena Velez          elena.velez@tractchun.com
# 3          4      Barraza Alberto      alberto.barraza@tractchun.com
# 4          5  Willyberto Gonzales  willyberto.gonzales@tractchun.com
#
#   Fecha de Nacimiento
# 0           1989/4/28
# 1            1979/1/1
# 2            1993/6/6
# 3          1978/10/20
# 4           1973/5/11

# %%
año_2016 = pd.read_excel("data/2016.xlsx")
año_2016.head()
# Out:
#            ID Ticket      Fecha  ID Empleado  ID Agente      Categoría  \
# 0  GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1  GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2  GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 3  GDDTSR-5942488006 2016-04-28        320.0       40.0        Sistema
# 4  GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
#
#         Tipo           Severidad        Prioridad  Días Resolución  \
# 0   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2   Problema  0 - Sin Clasificar  0 - Sin Asignar              3.0
# 3  Solicitud  0 - Sin Clasificar  0 - Sin Asignar              9.0
# 4   Problema          2 - Normal  0 - Sin Asignar              0.0
#
#    Satisfacción               Web  Índice
# 0           5.0  www.tractchun.es      1.0
# 1           5.0  www.tractchun.es      1.0
# 2           5.0  www.tractchun.es      1.0
# 3           5.0  www.tractchun.es      1.0
# 4           5.0  www.tractchun.es      1.0

# %% [markdown]
# 2. Haced una exploración básica de cada uno de los DataFrames, esta exploración debe incluir:
#
# ¿Cuántas filas y columnas tiene el DataFrame?
#
# Mostrad las primeras cinco filas y las últimas cinco filas del DataFrame.
#
# Mostrad 2 filas al azar del DataFrame.
#
# ¿Cuál es el nombre de las columnas del DataFrame?
#
# ¿Cuáles son los principales estádisticos del DataFrame? Mostrad por separado las variables categóricas y las variables numéricas.
#
# ¿Cuál es el porcentaje de valores nulos en cada columna?
#
# ¿Cuántos valores únicos tenemos para cada una de las columnas?
#
# De aquellas columnas que tengan menos de 6 elementos únicos mostrad cada uno de sus valores únicos.
#
# 📌 NOTA Fijaos que vamos a hacer lo mismo para cada archivo que tenemos. Una buena práctica sería crearnos una función que apliquemos a cada conjunto de datos. Nuestra función recibirá un parámetro, que será el dataframe entero
#
# 📌 NOTA Nos estamos convirtiendo en analistas de datos y no nos debe valer solo con escribir el código, os recomendamos que reviseis bien los resultados y empezais a extraer algunas conclusiones. ¿Hay datos raros en nuestros conjuntos de datos? ¿Tenemos nulos?, etc.

# %%
def exploracion(df):

    print(f"El dataframe tiene {df.shape[0]} filas y {df.shape[1]} columnas")  
    print("---")
    print(df.head())
    print("---")
    print(df.tail())
    print("---")
    print(df.sample(2))
    print("---")
    columnas = [df.columns[num] for num in range(len(df.columns))]
    print(f"Los nombres de las columnas son {columnas}")
    print("---")
    print(f"A continuación se muestran los principales estadísticos numéricos del dataframe {df}:")
    print(df.describe)
    print(f"A continuación se muestran los principales estadísticos categóricos del dataframe {df}:")
    print(df.describe(include = "object"))
    print("---")
    print("Los porcentajes de valores nulos por cada columna son:")
    print(df.isnull().sum() * 100/df.shape[0])
    print("---")
    valores_unicos = [len(df[col].value_counts())for col in columnas]
    valores_unicos_por_columna = list(zip(columnas, valores_unicos))
    print("Estas son las cantidades de valores únicos por cada columna")
    print(valores_unicos_por_columna)
    print("---")
    lista_valores_unicos = [df[tupla[0]].unique() for tupla in valores_unicos_por_columna if tupla[1] < 6]
    print("Estos son los valores únicos por cada columna que tenga menos de seis")
    print(lista_valores_unicos)

# %%
exploracion(empleados)
# Out:
# El dataframe tiene 2000 filas y 6 columnas
# ---
#   Turno  ID Empleado Apellido     Nombre ID Puesto  \
# 0     A            6    VILLA      JESUS  50-32200
# 1   NaN           10   MENDEZ    RICARDO  15-24100
# 2   NaN           21  HEREDIA  GUADALUPE  90-14000
# 3   NaN           27    DURAN    DESSENS  15-24100
# 4   NaN           29   LAGUNA   FEDERICO  80-24100
#
#                              Email
# 0        jesus.villa@tractchun.com
# 1     ricardo.mendez@tractchun.com
# 2  guadalupe.heredia@tractchun.com
# 3      dessens.duran@tractchun.com
# 4    federico.laguna@tractchun.com
# ---
#      Turno  ID Empleado  Apellido     Nombre ID Puesto  \
# 1995   NaN         1903     RAMOS       JOSE  55-23200
# 1996   NaN         1904      RUIZ  GUADALUPE  80-22220
# 1997   NaN         1935    ZEPEDA  FRANCISCO  15-24100
# 1998   NaN         1953    ROBLES  ELIZABETH  15-24100
# 1999   NaN         1993  ENRIQUEZ  HERCULANO  45-11000
#
#                                  Email
# 1995          jose.ramos@tractchun.com
# 1996      guadalupe.ruiz@tractchun.com
# 1997    francisco.zepeda@tractchun.com
# 1998    elizabeth.robles@tractchun.com
# 1999  herculano.enriquez@tractchun.com
# ---
#      Turno  ID Empleado  Apellido     Nombre ID Puesto  \
# 886    NaN          737  CARRILLO       LUIS  15-24100
# 1470   NaN         1397     PEREZ  FRANCISCO  55-23200
#
#                               Email
# 886     luis.carrillo@tractchun.com
# 1470  francisco.perez@tractchun.com
# ---
# Los nombres de las columnas son ['Turno', 'ID Empleado', 'Apellido', 'Nombre', 'ID Puesto', 'Email']
# ---
# A continuación se muestran los principales estadísticos numéricos del dataframe      Turno  ID Empleado  Apellido     Nombre ID Puesto  \
# 0        A            6     VILLA      JESUS  50-32200
# 1      NaN           10    MENDEZ    RICARDO  15-24100
# 2      NaN           21   HEREDIA  GUADALUPE  90-14000
# 3      NaN           27     DURAN    DESSENS  15-24100
# 4      NaN           29    LAGUNA   FEDERICO  80-24100
# ...    ...          ...       ...        ...       ...
# 1995   NaN         1903     RAMOS       JOSE  55-23200
# 1996   NaN         1904      RUIZ  GUADALUPE  80-22220
# 1997   NaN         1935    ZEPEDA  FRANCISCO  15-24100
# 1998   NaN         1953    ROBLES  ELIZABETH  15-24100
# 1999   NaN         1993  ENRIQUEZ  HERCULANO  45-11000
#
#                                  Email
# 0            jesus.villa@tractchun.com
# 1         ricardo.mendez@tractchun.com
# 2      guadalupe.heredia@tractchun.com
# 3          dessens.duran@tractchun.com
# 4        federico.laguna@tractchun.com
# ...                                ...
# 1995          jose.ramos@tractchun.com
# 1996      guadalupe.ruiz@tractchun.com
# 1997    francisco.zepeda@tractchun.com
# 1998    elizabeth.robles@tractchun.com
# 1999  herculano.enriquez@tractchun.com
#
# [2000 rows x 6 columns]:
# <bound method NDFrame.describe of      Turno  ID Empleado  Apellido     Nombre ID Puesto  \
# 0        A            6     VILLA      JESUS  50-32200
# 1      NaN           10    MENDEZ    RICARDO  15-24100
# 2      NaN           21   HEREDIA  GUADALUPE  90-14000
# 3      NaN           27     DURAN    DESSENS  15-24100
# 4      NaN           29    LAGUNA   FEDERICO  80-24100
# ...    ...          ...       ...        ...       ...
# 1995   NaN         1903     RAMOS       JOSE  55-23200
# 1996   NaN         1904      RUIZ  GUADALUPE  80-22220
# 1997   NaN         1935    ZEPEDA  FRANCISCO  15-24100
# 1998   NaN         1953    ROBLES  ELIZABETH  15-24100
# 1999   NaN         1993  ENRIQUEZ  HERCULANO  45-11000
#
#                                  Email
# 0            jesus.villa@tractchun.com
# 1         ricardo.mendez@tractchun.com
# 2      guadalupe.heredia@tractchun.com
# 3          dessens.duran@tractchun.com
# 4        federico.laguna@tractchun.com
# ...                                ...
# 1995          jose.ramos@tractchun.com
# 1996      guadalupe.ruiz@tractchun.com
# 1997    francisco.zepeda@tractchun.com
# 1998    elizabeth.robles@tractchun.com
# 1999  herculano.enriquez@tractchun.com
#
# [2000 rows x 6 columns]>
# A continuación se muestran los principales estadísticos categóricos del dataframe      Turno  ID Empleado  Apellido     Nombre ID Puesto  \
# 0        A            6     VILLA      JESUS  50-32200
# 1      NaN           10    MENDEZ    RICARDO  15-24100
# 2      NaN           21   HEREDIA  GUADALUPE  90-14000
# 3      NaN           27     DURAN    DESSENS  15-24100
# 4      NaN           29    LAGUNA   FEDERICO  80-24100
# ...    ...          ...       ...        ...       ...
# 1995   NaN         1903     RAMOS       JOSE  55-23200
# 1996   NaN         1904      RUIZ  GUADALUPE  80-22220
# 1997   NaN         1935    ZEPEDA  FRANCISCO  15-24100
# 1998   NaN         1953    ROBLES  ELIZABETH  15-24100
# 1999   NaN         1993  ENRIQUEZ  HERCULANO  45-11000
#
#                                  Email
# 0            jesus.villa@tractchun.com
# 1         ricardo.mendez@tractchun.com
# 2      guadalupe.heredia@tractchun.com
# 3          dessens.duran@tractchun.com
# 4        federico.laguna@tractchun.com
# ...                                ...
# 1995          jose.ramos@tractchun.com
# 1996      guadalupe.ruiz@tractchun.com
# 1997    francisco.zepeda@tractchun.com
# 1998    elizabeth.robles@tractchun.com
# 1999  herculano.enriquez@tractchun.com
#
# [2000 rows x 6 columns]:
#        Turno Apellido Nombre ID Puesto                      Email
# count      8     2000   2000      2000                       2000
# unique     4      376    565        75                       2000
# top        A    LOPEZ  MARIA  15-24100  jesus.villa@tractchun.com
# freq       2       36     46       407                          1
# ---
# Los porcentajes de valores nulos por cada columna son:
# Turno          99.6
# ID Empleado     0.0
# Apellido        0.0
# Nombre          0.0
# ID Puesto       0.0
# Email           0.0
# dtype: float64
# ---
# Estas son las cantidades de valores únicos por cada columna
# [('Turno', 4), ('ID Empleado', 2000), ('Apellido', 376), ('Nombre', 565), ('ID Puesto', 75), ('Email', 2000)]
# ---
# Estos son los valores únicos por cada columna que tenga menos de seis
# [array(['A', nan, 'B', 'C', 'D'], dtype=object)]

# %%
exploracion(agentes)
# Out:
# El dataframe tiene 50 filas y 4 columnas
# ---
#    ID Agente               Nombre                              email  \
# 0          1          Mata Lucero          lucero.mata@tractchun.com
# 1          2         JesusGrajeda        jesus.grajeda@tractchun.com
# 2          3          Elena Velez          elena.velez@tractchun.com
# 3          4      Barraza Alberto      alberto.barraza@tractchun.com
# 4          5  Willyberto Gonzales  willyberto.gonzales@tractchun.com
#
#   Fecha de Nacimiento
# 0           1989/4/28
# 1            1979/1/1
# 2            1993/6/6
# 3          1978/10/20
# 4           1973/5/11
# ---
#     ID Agente           Nombre                          email  \
# 45         46      Rosa Olguin      rosa.olguin@tractchun.com
# 46         47  Yomaira Agudelo  yomaira.agudelo@tractchun.com
# 47         48   Aurelio Tanori   aurelio.tanori@tractchun.com
# 48         49   Armando Sierra   armando.sierra@tractchun.com
# 49         50     Ramon Macias     ramon.macias@tractchun.com
#
#    Fecha de Nacimiento
# 45           1985/5/30
# 46          1974/12/15
# 47           1979/8/29
# 48            1991/4/5
# 49            1980/3/4
# ---
#     ID Agente         Nombre                        email Fecha de Nacimiento
# 36         37  Jesus Pacheco  jesus.pacheco@tractchun.com           1980/6/15
# 5           6       A. Trejo  alberto.trejo@tractchun.com            1988/3/9
# ---
# Los nombres de las columnas son ['ID Agente', 'Nombre', 'email', 'Fecha de Nacimiento']
# ---
# A continuación se muestran los principales estadísticos numéricos del dataframe     ID Agente                Nombre                               email  \
# 0           1           Mata Lucero           lucero.mata@tractchun.com
# 1           2          JesusGrajeda         jesus.grajeda@tractchun.com
# 2           3           Elena Velez           elena.velez@tractchun.com
# 3           4       Barraza Alberto       alberto.barraza@tractchun.com
# 4           5   Willyberto Gonzales   willyberto.gonzales@tractchun.com
# 5           6              A. Trejo         alberto.trejo@tractchun.com
# 6           7        Estuardo Ocaño        estuardo.ocaño@tractchun.com
# 7           8    Marisol Piedrahita    marisol.piedrahita@tractchun.com
# 8           9        Velasquez Jose        jose.velasquez@tractchun.com
# 9          10      Alberto Casillas      alberto.casillas@tractchun.com
# 10         11          Lopez Moran.           lopez.moran@tractchun.com
# 11         12             Javier D.         javier.davila@tractchun.com
# 12         13      Griselda Galindo      griselda.galindo@tractchun.com
# 13         14        EstuardoTorres       estuardo.torres@tractchun.com
# 14         15     Galindo Guadalupe     guadalupe.galindo@tractchun.com
# 15         16           Orci Carlos           carlos.orci@tractchun.com
# 16         17          Leon Lourdes          lourdes.leon@tractchun.com
# 17         18        Miller Gaviria        miller.gaviria@tractchun.com
# 18         19       Alfonso Barraza       alfonso.barraza@tractchun.com
# 19         20          Eduardo Luna          eduardo.luna@tractchun.com
# 20         21      Alberto Gastelum      alberto.gastelum@tractchun.com
# 21         22                Lorena           lorena.leon@tractchun.com
# 22         23   Guadalupe Hernandez   guadalupe.hernandez@tractchun.com
# 23         24      Barbara Grijalva      barbara.grijalva@tractchun.com
# 24         25         Sandra Lujan           sandra.lujan@tractchun.com
# 25         26         Flores Sierra         flores.sierra@tractchun.com
# 26         27           Isela Leyva           isela.leyva@tractchun.com
# 27         28          Nurio Zepeda          nurio.zepeda@tractchun.com
# 28         29         Segura Garcia         segura.garcia@tractchun.com
# 29         30            Parra Luna            parra.luna@tractchun.com
# 30         31     Guadalupe Torrico     guadalupe.torrico@tractchun.com
# 31         32        Silvia Morales        silvia.morales@tractchun.com
# 32         33  Guadalupe Villanueva  guadalupe.villanueva@tractchun.com
# 33         34            Diana Rojo            diana.rojo@tractchun.com
# 34         35               Melinda       melinda.barcelo@tractchun.com
# 35         36           Luis Torres           luis.torres@tractchun.com
# 36         37         Jesus Pacheco         jesus.pacheco@tractchun.com
# 37         38       Enrique Montiel       enrique.montiel@tractchun.com
# 38         39       Jesus Contreras       jesus.contreras@tractchun.com
# 39         40      Alfredo Barreras      alfredo.barreras@tractchun.com
# 40         41         Aldo Carrillo         aldo.carrillo@tractchun.com
# 41         42             Darwin E.      darwin.echeverry@tractchun.com
# 42         43       Reyna Santacruz       reyna.santacruz@tractchun.com
# 22           1986/6/12
# 23            1972/6/5
# 24          1988/11/17
# 25           1982/3/15
# 26           1987/4/18
# 27            1982/4/4
# 28          1972/11/14
# 29           1995/6/17
# 30           1993/3/18
# 31           1980/6/16
# 32           1975/1/15
# 33            1996/3/9
# 34           1996/5/30
# 35           1982/7/18
# 36           1980/6/15
# 37           1985/2/27
# 38          1983/10/20
# 39          1974/10/19
# 40            1982/8/1
# 41           1991/7/16
# 42            1984/6/7
# 43           1987/10/4
# 44           1982/9/22
# 45           1985/5/30
# 46          1974/12/15
# 47           1979/8/29
# 48            1991/4/5
# 49            1980/3/4  :
#              Nombre                      email Fecha de Nacimiento
# count            50                         50                  50
# unique           50                         50                  50
# top     Mata Lucero  lucero.mata@tractchun.com           1989/4/28
# freq              1                          1                   1
# ---
# Los porcentajes de valores nulos por cada columna son:
# ID Agente              0.0
# Nombre                 0.0
# email                  0.0
# Fecha de Nacimiento    0.0
# dtype: float64
# ---
# Estas son las cantidades de valores únicos por cada columna
# [('ID Agente', 50), ('Nombre', 50), ('email', 50), ('Fecha de Nacimiento', 50)]
# ---
# Estos son los valores únicos por cada columna que tenga menos de seis
# []

# %%
exploracion(año_2016)
# Out:
# El dataframe tiene 13051 filas y 12 columnas
# ---
#            ID Ticket      Fecha  ID Empleado  ID Agente      Categoría  \
# 0  GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1  GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2  GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 3  GDDTSR-5942488006 2016-04-28        320.0       40.0        Sistema
# 4  GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
#
#         Tipo           Severidad        Prioridad  Días Resolución  \
# 0   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2   Problema  0 - Sin Clasificar  0 - Sin Asignar              3.0
# 3  Solicitud  0 - Sin Clasificar  0 - Sin Asignar              9.0
# 4   Problema          2 - Normal  0 - Sin Asignar              0.0
#
#    Satisfacción               Web  Índice
# 0           5.0  www.tractchun.es      1.0
# 1           5.0  www.tractchun.es      1.0
# 2           5.0  www.tractchun.es      1.0
# 3           5.0  www.tractchun.es      1.0
# 4           5.0  www.tractchun.es      1.0
# ---
#                ID Ticket      Fecha  ID Empleado  ID Agente Categoría  \
# 13046  TWRTSR-6442574526 2016-07-23        962.0       25.0   Sistema
# 13047  TWRTSR-7142570866 2016-07-19        126.0       38.0   Sistema
# 13048  TWRTSR-7742498308 2016-05-08        510.0        3.0   Sistema
# 13049  TWRTSR-8642558628 2016-07-07       1942.0       26.0   Sistema
# 13050  TWRTSR-8742628897 2016-09-15        919.0        8.0   Sistema
#
#             Tipo  Severidad Prioridad  Días Resolución  Satisfacción  \
# 13046  Solicitud  1 - Menor  1 - Baja             14.0           4.0
# 13047  Solicitud  3 - Mayor  1 - Baja             13.0           5.0
# 13048  Solicitud  3 - Mayor  1 - Baja              2.0           5.0
# 13049  Solicitud  1 - Menor  1 - Baja             16.0           4.0
# 13050  Solicitud  1 - Menor  1 - Baja              7.0           4.0
#
#                     Web  Índice
# 13046  www.tractchun.es      1.0
# 13047  www.tractchun.es      1.0
# 13048  www.tractchun.es      1.0
# 13049  www.tractchun.es      1.0
# 13050  www.tractchun.es      1.0
# ---
#                ID Ticket      Fecha  ID Empleado  ID Agente      Categoría  \
# 12807  TWLTNR-0042642269 2016-09-29       1266.0        2.0  Acceso&%Login
# 11467  THLESR-8142567167 2016-07-16       1046.0       11.0        Sistema
#
#             Tipo   Severidad Prioridad  Días Resolución  Satisfacción  \
# 12807  Solicitud  2 - Normal  1 - Baja              0.0           5.0
# 11467   Problema  2 - Normal  3 - Alta              1.0           5.0
#
#                     Web  Índice
# 12807  www.tractchun.es      1.0
# 11467  www.tractchun.es      1.0
# ---
# Los nombres de las columnas son ['ID Ticket', 'Fecha', 'ID Empleado', 'ID Agente', 'Categoría', 'Tipo', 'Severidad', 'Prioridad', 'Días Resolución', 'Satisfacción', 'Web', 'Índice ']
# ---
# A continuación se muestran los principales estadísticos numéricos del dataframe                ID Ticket      Fecha  ID Empleado  ID Agente      Categoría  \
# 0      GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1      GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2      GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 3      GDDTSR-5942488006 2016-04-28        320.0       40.0        Sistema
# 4      GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
# ...                  ...        ...          ...        ...            ...
# 13046  TWRTSR-6442574526 2016-07-23        962.0       25.0        Sistema
# 13047  TWRTSR-7142570866 2016-07-19        126.0       38.0        Sistema
# 13048  TWRTSR-7742498308 2016-05-08        510.0        3.0        Sistema
# 13049  TWRTSR-8642558628 2016-07-07       1942.0       26.0        Sistema
# 13050  TWRTSR-8742628897 2016-09-15        919.0        8.0        Sistema
#
#             Tipo           Severidad        Prioridad  Días Resolución  \
# 0       Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1       Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2       Problema  0 - Sin Clasificar  0 - Sin Asignar              3.0
# 3      Solicitud  0 - Sin Clasificar  0 - Sin Asignar              9.0
# 4       Problema          2 - Normal  0 - Sin Asignar              0.0
# ...          ...                 ...              ...              ...
# 13046  Solicitud           1 - Menor         1 - Baja             14.0
# 13047  Solicitud           3 - Mayor         1 - Baja             13.0
# 13048  Solicitud           3 - Mayor         1 - Baja              2.0
# 13049  Solicitud           1 - Menor         1 - Baja             16.0
# 13050  Solicitud           1 - Menor         1 - Baja              7.0
#
#        Satisfacción               Web  Índice
# 0               5.0  www.tractchun.es      1.0
# 1               5.0  www.tractchun.es      1.0
# 2               5.0  www.tractchun.es      1.0
# 3               5.0  www.tractchun.es      1.0
# 4               5.0  www.tractchun.es      1.0
# ...             ...               ...      ...
# 13046           4.0  www.tractchun.es      1.0
# 13047           5.0  www.tractchun.es      1.0
# 13048           5.0  www.tractchun.es      1.0
# 13049           4.0  www.tractchun.es      1.0
# 13050           4.0  www.tractchun.es      1.0
#
# [13051 rows x 12 columns]:
# <bound method NDFrame.describe of                ID Ticket      Fecha  ID Empleado  ID Agente      Categoría  \
# 0      GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1      GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2      GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 3      GDDTSR-5942488006 2016-04-28        320.0       40.0        Sistema
# 4      GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
# ...                  ...        ...          ...        ...            ...
# 13046  TWRTSR-6442574526 2016-07-23        962.0       25.0        Sistema
# 13047  TWRTSR-7142570866 2016-07-19        126.0       38.0        Sistema
# 13048  TWRTSR-7742498308 2016-05-08        510.0        3.0        Sistema
# 13049  TWRTSR-8642558628 2016-07-07       1942.0       26.0        Sistema
# 13050  TWRTSR-8742628897 2016-09-15        919.0        8.0        Sistema
#
#             Tipo           Severidad        Prioridad  Días Resolución  \
# 0       Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1       Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2       Problema  0 - Sin Clasificar  0 - Sin Asignar              3.0
# 3      Solicitud  0 - Sin Clasificar  0 - Sin Asignar              9.0
# 4       Problema          2 - Normal  0 - Sin Asignar              0.0
# ...          ...                 ...              ...              ...
# 13046  Solicitud           1 - Menor         1 - Baja             14.0
# 13047  Solicitud           3 - Mayor         1 - Baja             13.0
# 13048  Solicitud           3 - Mayor         1 - Baja              2.0
# 13049  Solicitud           1 - Menor         1 - Baja             16.0
# 13050  Solicitud           1 - Menor         1 - Baja              7.0
#
#        Satisfacción               Web  Índice
# 0               5.0  www.tractchun.es      1.0
# 1               5.0  www.tractchun.es      1.0
# 2               5.0  www.tractchun.es      1.0
# 3               5.0  www.tractchun.es      1.0
# 4               5.0  www.tractchun.es      1.0
# ...             ...               ...      ...
# 13046           4.0  www.tractchun.es      1.0
# 13047           5.0  www.tractchun.es      1.0
# 13048           5.0  www.tractchun.es      1.0
# 13049           4.0  www.tractchun.es      1.0
# 13050           4.0  www.tractchun.es      1.0
#
# [13051 rows x 12 columns]>
# A continuación se muestran los principales estadísticos categóricos del dataframe                ID Ticket      Fecha  ID Empleado  ID Agente      Categoría  \
# 0      GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1      GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2      GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 3      GDDTSR-5942488006 2016-04-28        320.0       40.0        Sistema
# 4      GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
# ...                  ...        ...          ...        ...            ...
# 13046  TWRTSR-6442574526 2016-07-23        962.0       25.0        Sistema
# 13047  TWRTSR-7142570866 2016-07-19        126.0       38.0        Sistema
# 13048  TWRTSR-7742498308 2016-05-08        510.0        3.0        Sistema
# 13049  TWRTSR-8642558628 2016-07-07       1942.0       26.0        Sistema
# 13050  TWRTSR-8742628897 2016-09-15        919.0        8.0        Sistema
#
#             Tipo           Severidad        Prioridad  Días Resolución  \
# 0       Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1       Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2       Problema  0 - Sin Clasificar  0 - Sin Asignar              3.0
# 3      Solicitud  0 - Sin Clasificar  0 - Sin Asignar              9.0
# 4       Problema          2 - Normal  0 - Sin Asignar              0.0
# ...          ...                 ...              ...              ...
# 13046  Solicitud           1 - Menor         1 - Baja             14.0
# 13047  Solicitud           3 - Mayor         1 - Baja             13.0
# 13048  Solicitud           3 - Mayor         1 - Baja              2.0
# 13049  Solicitud           1 - Menor         1 - Baja             16.0
# 13050  Solicitud           1 - Menor         1 - Baja              7.0
#
#        Satisfacción               Web  Índice
# 0               5.0  www.tractchun.es      1.0
# 1               5.0  www.tractchun.es      1.0
# 2               5.0  www.tractchun.es      1.0
# 3               5.0  www.tractchun.es      1.0
# 4               5.0  www.tractchun.es      1.0
# ...             ...               ...      ...
# 13046           4.0  www.tractchun.es      1.0
# 13047           5.0  www.tractchun.es      1.0
# 13048           5.0  www.tractchun.es      1.0
# 13049           4.0  www.tractchun.es      1.0
# 13050           4.0  www.tractchun.es      1.0
#
# [13051 rows x 12 columns]:
#                 ID Ticket Categoría       Tipo   Severidad Prioridad  \
# count               13050     13038      13050       13025     13025
# unique              13050         4          2           5         4
# top     GDDENR-5042564453   Sistema  Solicitud  2 - Normal  3 - Alta
# freq                    1      5247       9756       11771      4828
#
#                      Web
# count              13024
# unique                 1
# top     www.tractchun.es
# freq               13024
# ---
# Los porcentajes de valores nulos por cada columna son:
# ID Ticket          0.007662
# Fecha              0.199218
# ID Empleado        0.015324
# ID Agente          0.007662
# Categoría          0.099609
# Tipo               0.007662
# Severidad          0.199218
# Prioridad          0.199218
# Días Resolución    0.015324
# Satisfacción       0.107271
# Web                0.206881
# Índice             0.099609
# dtype: float64
# ---
# Estas son las cantidades de valores únicos por cada columna
# [('ID Ticket', 13050), ('Fecha', 366), ('ID Empleado', 1999), ('ID Agente', 50), ('Categoría', 4), ('Tipo', 2), ('Severidad', 5), ('Prioridad', 4), ('Días Resolución', 21), ('Satisfacción', 5), ('Web', 1), ('Índice ', 1)]
# ---
# Estos son los valores únicos por cada columna que tenga menos de seis
# [array(['Acceso&%Login', 'Sistema', 'Software', 'Hardware', nan],
#       dtype=object), array(['Problema', 'Solicitud', nan], dtype=object), array(['0 - Sin Clasificar', '2 - Normal', '4 - Crítico', nan,
#        '3 - Mayor', '1 - Menor'], dtype=object), array(['0 - Sin Asignar', nan, '3 - Alta', '2 - Media', '1 - Baja'],
#       dtype=object), array([ 5.,  1.,  4., nan,  3.,  2.]), array(['www.tractchun.es', nan], dtype=object), array([ 1., nan])]

# %% [markdown]
# 3. Modificaciones básicas de los conjuntos de datos:
#
# Cambiad el nombre de las columnas para que todas estén en minúsculas y reemplazad los espacios por _.
#
# Para las columnas de web e índice en el archovo de 2016.xlsx ya hemos visto que tiene un único valor único, lo cual no tiene mucho sentido ya que no nos aporta información útil. En este ejercicios tendréis que eliminar dichas columnas del dataframe.
#
# Establece la columna id_ticket de la tabla de 2016.xlsx como índice del DataFrame.

# %%
def renombrando(df):
    nombres_de_columnas = {col : col.lower().replace(" ", "_") for col in df.columns}
    df.rename(columns = nombres_de_columnas, inplace = True)

# %%
renombrando(empleados)
empleados.head()
# Out:
#   turno  id_empleado apellido     nombre id_puesto  \
# 0     A            6    VILLA      JESUS  50-32200
# 1   NaN           10   MENDEZ    RICARDO  15-24100
# 2   NaN           21  HEREDIA  GUADALUPE  90-14000
# 3   NaN           27    DURAN    DESSENS  15-24100
# 4   NaN           29   LAGUNA   FEDERICO  80-24100
#
#                              email
# 0        jesus.villa@tractchun.com
# 1     ricardo.mendez@tractchun.com
# 2  guadalupe.heredia@tractchun.com
# 3      dessens.duran@tractchun.com
# 4    federico.laguna@tractchun.com

# %%
renombrando(agentes)
agentes.head()
# Out:
#    id_agente               nombre                              email  \
# 0          1          Mata Lucero          lucero.mata@tractchun.com
# 1          2         JesusGrajeda        jesus.grajeda@tractchun.com
# 2          3          Elena Velez          elena.velez@tractchun.com
# 3          4      Barraza Alberto      alberto.barraza@tractchun.com
# 4          5  Willyberto Gonzales  willyberto.gonzales@tractchun.com
#
#   fecha_de_nacimiento
# 0           1989/4/28
# 1            1979/1/1
# 2            1993/6/6
# 3          1978/10/20
# 4           1973/5/11

# %%
renombrando(año_2016)
año_2016.head()
# Out:
#            id_ticket      fecha  id_empleado  id_agente      categoría  \
# 0  GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1  GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2  GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 3  GDDTSR-5942488006 2016-04-28        320.0       40.0        Sistema
# 4  GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
#
#         tipo           severidad        prioridad  días_resolución  \
# 0   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2   Problema  0 - Sin Clasificar  0 - Sin Asignar              3.0
# 3  Solicitud  0 - Sin Clasificar  0 - Sin Asignar              9.0
# 4   Problema          2 - Normal  0 - Sin Asignar              0.0
#
#    satisfacción               web  índice_
# 0           5.0  www.tractchun.es      1.0
# 1           5.0  www.tractchun.es      1.0
# 2           5.0  www.tractchun.es      1.0
# 3           5.0  www.tractchun.es      1.0
# 4           5.0  www.tractchun.es      1.0

# %%
eliminar = año_2016.drop(["web", "índice_"], axis = 1)
eliminar
# Out:
#                id_ticket      fecha  id_empleado  id_agente      categoría  \
# 0      GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1      GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2      GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 3      GDDTSR-5942488006 2016-04-28        320.0       40.0        Sistema
# 4      GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
# ...                  ...        ...          ...        ...            ...
# 13046  TWRTSR-6442574526 2016-07-23        962.0       25.0        Sistema
# 13047  TWRTSR-7142570866 2016-07-19        126.0       38.0        Sistema
# 13048  TWRTSR-7742498308 2016-05-08        510.0        3.0        Sistema
# 13049  TWRTSR-8642558628 2016-07-07       1942.0       26.0        Sistema
# 13050  TWRTSR-8742628897 2016-09-15        919.0        8.0        Sistema
#
#             tipo           severidad        prioridad  días_resolución  \
# 0       Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1       Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2       Problema  0 - Sin Clasificar  0 - Sin Asignar              3.0
# 3      Solicitud  0 - Sin Clasificar  0 - Sin Asignar              9.0
# 4       Problema          2 - Normal  0 - Sin Asignar              0.0
# ...          ...                 ...              ...              ...
# 13046  Solicitud           1 - Menor         1 - Baja             14.0
# 13047  Solicitud           3 - Mayor         1 - Baja             13.0
# 13048  Solicitud           3 - Mayor         1 - Baja              2.0
# 13049  Solicitud           1 - Menor         1 - Baja             16.0
# 13050  Solicitud           1 - Menor         1 - Baja              7.0
#
#        satisfacción
# 0               5.0
# 1               5.0
# 2               5.0
# 3               5.0
# 4               5.0
# ...             ...
# 13046           4.0
# 13047           5.0
# 13048           5.0
# 13049           4.0
# 13050           4.0
#
# [13051 rows x 10 columns]

# %%
año_2016.set_index(["id_ticket"], inplace = True)
año_2016.head()
# Out:
#                        fecha  id_empleado  id_agente      categoría  \
# id_ticket
# GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# GDDTSR-5942488006 2016-04-28        320.0       40.0        Sistema
# GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
#
#                         tipo           severidad        prioridad  \
# id_ticket
# GDDENR-5042564453   Problema  0 - Sin Clasificar  0 - Sin Asignar
# GDDENR-8042508060   Problema  0 - Sin Clasificar  0 - Sin Asignar
# GDDESR-1342539995   Problema  0 - Sin Clasificar  0 - Sin Asignar
# GDDTSR-5942488006  Solicitud  0 - Sin Clasificar  0 - Sin Asignar
# GDLEER-0042524120   Problema          2 - Normal  0 - Sin Asignar
#
#                    días_resolución  satisfacción               web  índice_
# id_ticket
# GDDENR-5042564453              0.0           5.0  www.tractchun.es      1.0
# GDDENR-8042508060              0.0           5.0  www.tractchun.es      1.0
# GDDESR-1342539995              3.0           5.0  www.tractchun.es      1.0
# GDDTSR-5942488006              9.0           5.0  www.tractchun.es      1.0
# GDLEER-0042524120              0.0           5.0  www.tractchun.es      1.0

# %% [markdown]
# 4. Guarda los csv's sobre los que hayáis hecho cambios para usarlos en próximos pairs .

# %%
empleados.to_csv("data/datos_guardados/empleados_procesado.csv")
agentes.to_csv("data/datos_guardados/agentes_procesado.csv")
año_2016.to_csv("data/datos_guardados/2016_procesado.csv")
