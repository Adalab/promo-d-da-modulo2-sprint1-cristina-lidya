# %% [markdown]
# # **Ejercicios de pair programming Módulo 2 Sprint 1**
# ## **Pandas: Lección 7**
# ### **Apply**

# %%
import pandas as pd
import datetime as dt
import numpy as np
import re

# %% [markdown]
# En los ejercicios de hoy pondremos en práctica los apply, y nos crearemos algunas funciones que nos van a permitir limpiar un poco los datos, para que podamos extraer conclusiones de una forma más sencilla. Para ellos seguiremos trabajando con mismos csv que en el pair anterior, el de los empleados que unimos en el pair de unión de datasets y el de los tickets de todos los años. Para ello, lo primero que tendremos que hacer es cargar estos dos csv.
#
# Como hemos dicho hasta ahora, hemos estado explorando los datos, y puede que ya nos hayamos dado cuenta de que hay columnas de que están un poco "sucias". Hoy limpiaremos esas columnas para poder extraer conclusiones más eficaces.

# %%
años_2016_2020 = pd.read_csv("data/datos_guardados/años_2016_2020.csv")
años_2016_2020
# Out:
#                id_ticket   año                fecha  id_empleado  id_agente  \
# 0      GDDENR-5042564453  2016           2016-07-13       1735.0        4.0
# 1      GDDENR-8042508060  2016           2016-05-18       1566.0       10.0
# 2      GDDESR-1342539995  2016           2016-06-18        569.0       29.0
# 3      GDDTSR-5942488006  2016           2016-04-28        320.0       40.0
# 4      GDLEER-0042524120  2016           2016-06-03       1842.0       31.0
# ...                  ...   ...                  ...          ...        ...
# 97381  TWRTSR-8543883120  2020  2020-02-22 00:00:00       1142.0        1.0
# 97382  TWRTSR-8744097039  2020  2020-09-23 00:00:00        223.0       40.0
# 97383  TWRTSR-9643846768  2020  2020-01-16 00:00:00        256.0        7.0
# 97384  TWRTSR-9944138906  2020  2020-11-03 00:00:00       1060.0        9.0
# 97385  TWRTST-8643986162  2020  2020-06-04 00:00:00       1876.0       41.0
#
#            categoría       tipo           severidad        prioridad  \
# 0      Acceso&%Login   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 1      Acceso&%Login   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 2            Sistema   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 3            Sistema  Solicitud  0 - Sin Clasificar  0 - Sin Asignar
# 4           Software   Problema          2 - Normal  0 - Sin Asignar
# ...              ...        ...                 ...              ...
# 97381        Sistema  Solicitud           3 - Mayor         1 - Baja
# 97382        Sistema  Solicitud           1 - Menor         1 - Baja
# 97383        Sistema  Solicitud           3 - Mayor         1 - Baja
# 97384        Sistema  Solicitud           1 - Menor         1 - Baja
# 97385        Sistema  Solicitud           1 - Menor         1 - Baja
#
#        días_resolución  satisfacción
# 0                  0.0           5.0
# 1                  0.0           5.0
# 2                  3.0           5.0
# 3                  9.0           5.0
# 4                  0.0           5.0
# ...                ...           ...
# 97381             11.0           5.0
# 97382              7.0           4.0
# 97383             13.0           5.0
# 97384              9.0           5.0
# 97385              6.0           4.0
#
# [97386 rows x 11 columns]

# %%
empleados_puestos = pd.read_csv("data/datos_guardados/empleados_puestos.csv")
empleados_puestos
# Out:
#      turno  id_empleado    apellido    nombre id_puesto  \
# 0        A          6.0       VILLA     JESUS  50-32200
# 1      NaN         60.0        DIAZ  PATRICIA  50-32200
# 2        B          2.0      DUARTE   ANTONIO  50-32200
# 3      NaN         24.0  VILLANUEVA     JESUS  50-32200
# 4      NaN         98.0    GALLEGOS  PATRICIA  50-32200
# ...    ...          ...         ...       ...       ...
# 2017   NaN          NaN         NaN       NaN  80-27000
# 2018   NaN          NaN         NaN       NaN  90-14110
# 2019   NaN          NaN         NaN       NaN  90-18000
# 2020   NaN          NaN         NaN       NaN  90-23200
# 2021   NaN          NaN         NaN       NaN  90-26100
#
#                                 email                            puesto  \
# 0           jesus.villa@tractchun.com           Comprador de Materiales
# 1         patricia.diaz@tractchun.com           Comprador de Materiales
# 2        antonio.duarte@tractchun.com           Comprador de Materiales
# 3      jesus.villanueva@tractchun.com           Comprador de Materiales
# 4     patricia.gallegos@tractchun.com           Comprador de Materiales
# ...                               ...                               ...
# 2017                              NaN  Supervisor General de Producción
# 2018                              NaN                Tecnico de Calidad
# 2019                              NaN  Gerente de Ingenieria de Calidad
# 2020                              NaN          Ingeniero de Manufactura
# 2021                              NaN                  Clerk de Copiado
#
#                departamento     tipo_puesto
# 0     CONTROL DE PRODUCCION  Administrativo
# 1     CONTROL DE PRODUCCION  Administrativo
# 2     CONTROL DE PRODUCCION  Administrativo
# 3     CONTROL DE PRODUCCION  Administrativo
# 4     CONTROL DE PRODUCCION  Administrativo
# ...                     ...             ...
# 2017          MANTENIMIENTO   Mandos Medios
# 2018  INGENIERIA DE CALIDAD       Operativo
# 2019  INGENIERIA DE CALIDAD        Gerencia
# 2020  INGENIERIA DE CALIDAD       Operativo
# 2021  INGENIERIA DE CALIDAD  Administrativo
#
# [2022 rows x 9 columns]

# %% [markdown]
# Manos a la obra 💪🏽! Los objetivos de la clase de hoy son:
#
# 1. Cread una columna nueva y una función que nos de el mes en el que se solicitó el servicio. Tened en cuenta que todas las filas tienen la misma estructura. A la hora de escribir la función debemos tener en cuenta que puede que no haya la información de mes en la columna de la fecha. En ese caso devolved un nulo (NaN).
#
# 📌 Nota La fecha tendrá que ir formato de string como "Enero", "Febrero", etc.
# 💡 Pista 💡Podréis usar regex, pero no es estrictamente necesario.

# %%
años_2016_2020["fecha"] = años_2016_2020["fecha"].apply(pd.to_datetime)

# %%
def mes(m):
    try:
        return m.strftime("%B")
    except:
        return np.nan

# %%
años_2016_2020["mes"] = años_2016_2020["fecha"].apply(mes)

# %%
años_2016_2020
# Out:
#                id_ticket   año      fecha  id_empleado  id_agente  \
# 0      GDDENR-5042564453  2016 2016-07-13       1735.0        4.0
# 1      GDDENR-8042508060  2016 2016-05-18       1566.0       10.0
# 2      GDDESR-1342539995  2016 2016-06-18        569.0       29.0
# 3      GDDTSR-5942488006  2016 2016-04-28        320.0       40.0
# 4      GDLEER-0042524120  2016 2016-06-03       1842.0       31.0
# ...                  ...   ...        ...          ...        ...
# 97381  TWRTSR-8543883120  2020 2020-02-22       1142.0        1.0
# 97382  TWRTSR-8744097039  2020 2020-09-23        223.0       40.0
# 97383  TWRTSR-9643846768  2020 2020-01-16        256.0        7.0
# 97384  TWRTSR-9944138906  2020 2020-11-03       1060.0        9.0
# 97385  TWRTST-8643986162  2020 2020-06-04       1876.0       41.0
#
#            categoría       tipo           severidad        prioridad  \
# 0      Acceso&%Login   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 1      Acceso&%Login   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 2            Sistema   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 3            Sistema  Solicitud  0 - Sin Clasificar  0 - Sin Asignar
# 4           Software   Problema          2 - Normal  0 - Sin Asignar
# ...              ...        ...                 ...              ...
# 97381        Sistema  Solicitud           3 - Mayor         1 - Baja
# 97382        Sistema  Solicitud           1 - Menor         1 - Baja
# 97383        Sistema  Solicitud           3 - Mayor         1 - Baja
# 97384        Sistema  Solicitud           1 - Menor         1 - Baja
# 97385        Sistema  Solicitud           1 - Menor         1 - Baja
#
#        días_resolución  satisfacción        mes
# 0                  0.0           5.0       July
# 1                  0.0           5.0        May
# 2                  3.0           5.0       June
# 3                  9.0           5.0      April
# 4                  0.0           5.0       June
# ...                ...           ...        ...
# 97381             11.0           5.0   February
# 97382              7.0           4.0  September
# 97383             13.0           5.0    January
# 97384              9.0           5.0   November
# 97385              6.0           4.0       June
#
# [97386 rows x 12 columns]

# %% [markdown]
# 2. En la tabla de empleados, tenemos los nombres y los apellidos de los empleados, pero en columnas separadas.
# En los ejercicios de pair de la lección del groupby vimos que si quisieramos agrupar por los nombres, esto se nos puede complicar.
# Ahora nos piden que creemos una columna donde tengamos el nombre y el apellido juntos.
#
# 📌 NOTA La columna nueva debe tener el nombre y apellido con la primera letra en mayúsculas, por ejemplo "Jesús Villa".
# 📌 NOTA Una vez hallamos creado la columna nueva, eliminad las columnas de nombre y apellido originales.

# %%
def nombre_completo(nombre, apellido):
    try:
        return (nombre + " " + apellido).title()
    except: 
        return np.nan

# %%
empleados_puestos["nombre_completo"] = empleados_puestos.apply(lambda dataframe: nombre_completo(dataframe["nombre"], dataframe["apellido"]), axis = 1)

# %%
empleados_puestos.drop(["nombre", "apellido"], axis = 1)
# Out:
#      turno  id_empleado id_puesto                            email  \
# 0        A          6.0  50-32200        jesus.villa@tractchun.com
# 1      NaN         60.0  50-32200      patricia.diaz@tractchun.com
# 2        B          2.0  50-32200     antonio.duarte@tractchun.com
# 3      NaN         24.0  50-32200   jesus.villanueva@tractchun.com
# 4      NaN         98.0  50-32200  patricia.gallegos@tractchun.com
# ...    ...          ...       ...                              ...
# 2017   NaN          NaN  80-27000                              NaN
# 2018   NaN          NaN  90-14110                              NaN
# 2019   NaN          NaN  90-18000                              NaN
# 2020   NaN          NaN  90-23200                              NaN
# 2021   NaN          NaN  90-26100                              NaN
#
#                                 puesto           departamento     tipo_puesto  \
# 0              Comprador de Materiales  CONTROL DE PRODUCCION  Administrativo
# 1              Comprador de Materiales  CONTROL DE PRODUCCION  Administrativo
# 2              Comprador de Materiales  CONTROL DE PRODUCCION  Administrativo
# 3              Comprador de Materiales  CONTROL DE PRODUCCION  Administrativo
# 4              Comprador de Materiales  CONTROL DE PRODUCCION  Administrativo
# ...                                ...                    ...             ...
# 2017  Supervisor General de Producción          MANTENIMIENTO   Mandos Medios
# 2018                Tecnico de Calidad  INGENIERIA DE CALIDAD       Operativo
# 2019  Gerente de Ingenieria de Calidad  INGENIERIA DE CALIDAD        Gerencia
# 2020          Ingeniero de Manufactura  INGENIERIA DE CALIDAD       Operativo
# 2021                  Clerk de Copiado  INGENIERIA DE CALIDAD  Administrativo
#
#         nombre_completo
# 0           Jesus Villa
# 1         Patricia Diaz
# 2        Antonio Duarte
# 3      Jesus Villanueva
# 4     Patricia Gallegos
# ...                 ...
# 2017                NaN
# 2018                NaN
# 2019                NaN
# 2020                NaN
# 2021                NaN
#
# [2022 rows x 8 columns]

# %% [markdown]
# 3. En el pair programming desde a dirección nos pedían que agruparamos los datos en base a la columna de "categoría", puede que en aquel momento nos dieramos cuenta que había varías categorías que eran igual (en concreto "Acceso Login") pero que en algunos casos tenía unos símbolos raros (&, %, -). Es el momento de limpiar esta columna. El objetivo, reemplazar todos estos símbolos raros por "/", para conseguir homogeneizar los valores de esta columna. Para ellos deberemos crear una función.

# %%
def unificar(cat):
    return re.sub("^[A]\w*\W*\w*", "Acceso/Login", cat)

# %%
años_2016_2020["categoría"] = años_2016_2020["categoría"].apply(unificar)

# %%
años_2016_2020
# Out:
#                id_ticket   año      fecha  id_empleado  id_agente  \
# 0      GDDENR-5042564453  2016 2016-07-13       1735.0        4.0
# 1      GDDENR-8042508060  2016 2016-05-18       1566.0       10.0
# 2      GDDESR-1342539995  2016 2016-06-18        569.0       29.0
# 3      GDDTSR-5942488006  2016 2016-04-28        320.0       40.0
# 4      GDLEER-0042524120  2016 2016-06-03       1842.0       31.0
# ...                  ...   ...        ...          ...        ...
# 97381  TWRTSR-8543883120  2020 2020-02-22       1142.0        1.0
# 97382  TWRTSR-8744097039  2020 2020-09-23        223.0       40.0
# 97383  TWRTSR-9643846768  2020 2020-01-16        256.0        7.0
# 97384  TWRTSR-9944138906  2020 2020-11-03       1060.0        9.0
# 97385  TWRTST-8643986162  2020 2020-06-04       1876.0       41.0
#
#           categoría       tipo           severidad        prioridad  \
# 0      Acceso/Login   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 1      Acceso/Login   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 2           Sistema   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 3           Sistema  Solicitud  0 - Sin Clasificar  0 - Sin Asignar
# 4          Software   Problema          2 - Normal  0 - Sin Asignar
# ...             ...        ...                 ...              ...
# 97381       Sistema  Solicitud           3 - Mayor         1 - Baja
# 97382       Sistema  Solicitud           1 - Menor         1 - Baja
# 97383       Sistema  Solicitud           3 - Mayor         1 - Baja
# 97384       Sistema  Solicitud           1 - Menor         1 - Baja
# 97385       Sistema  Solicitud           1 - Menor         1 - Baja
#
#        días_resolución  satisfacción        mes
# 0                  0.0           5.0       July
# 1                  0.0           5.0        May
# 2                  3.0           5.0       June
# 3                  9.0           5.0      April
# 4                  0.0           5.0       June
# ...                ...           ...        ...
# 97381             11.0           5.0   February
# 97382              7.0           4.0  September
# 97383             13.0           5.0    January
# 97384              9.0           5.0   November
# 97385              6.0           4.0       June
#
# [97386 rows x 12 columns]

# %%
años_2016_2020["categoría"].unique()
# Out:
# array(['Acceso/Login', 'Sistema', 'Software', 'Hardware'], dtype=object)

# %% [markdown]
# 4. Una vez que hayáis terminado eliminad las columnas originales conservando las nuevas.

# %% [markdown]
# 5. Guardad el dataframe en un csv que usaremos más adelante
